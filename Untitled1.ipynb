# %% [markdown]
# <a href="https://colab.research.google.com/github/AATT2024/Innova/blob/Ejemplo-1/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Ejemplo en Colab")
plt.show()

# %% [markdown]
# Ejemplo práctico
